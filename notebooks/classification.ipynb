# %% [markdown]
# # fastText Commit Classification

# %% [markdown]
# In this notebook, we use a pre-trained fastText classification learned from labeled datasets to classify unlabeled commits gathered from Github.

# %% [markdown]
# ##### Import the required libraries

# %%
import pandas as pd
import sys

# %%
from fasttext import load_model

# %%
classifier = load_model("../data/commits.bin") 
df = pd.read_csv('../data/commits.csv',  lineterminator='\n', encoding="utf-8")
#df = df.dropna()
#df['message'] = df['message'].astype(str)

# %%
# replace \n with space
df = df.replace('\n','', regex=True)

# %%
# check the shape of the Github data
df.shape
# Out:
# (601077, 1)

# %%
df.columns
# Out:
# Index(['message'], dtype='object')

# %% [markdown]
# ##### Normalize the data

# %%
# convert the commit message column into string
commits = list(df['message'].astype(str))

# %% [markdown]
# ##### Predict using fastText

# %%
# predict the label with fastText
labels = classifier.predict(commits)

# %%
res = list(zip(*labels))
res_list = [x[0] for x in res]
lst2 = [item[0] for item in res_list]
df['labels_predicted'] = lst2

# %% [markdown]
# ##### Check the predictions made

# %%
df
# Out:
#                                                   message  \
# 0                  Use github's new relative path format.
# 1       Fix conditional variance of LS estimate.In 18....
# 2       Merge pull request #8 from cortex/masterShared...
# 3                 Integrate Mathieu Bryen's pull request.
# 4       Merge branch 'master' of github.com:mavam/stat...
# 5       Merge pull request #10 from cortex/mysql-utf8U...
# 6                               Merge branch 'mysql-utf8'
# 7                         Use UTF-8 for mysql connections
# 8       Please find an active fork for this project if...
# 9       Merge pull request #2 from mathbruyen/patch-1G...
# 10                                   Typo with latex code
# 11      Use modifyList for overriding arguments from s...
# 12           Documentation for shared connection settings
# 13      Merge branch 'master' of git@github.com:TTimo/...
# 14      Looked into getting the source compiled with M...
# 15      Merge pull request #27 from speps/masterFix fo...
# 16                                 Typo in balls and urns
# 17                               Trailing whitespace nit.
# 18                                        Update CHANGES.
# 19      Allow putting shared sql connection configurat...
# 20      Merge pull request #7 from cortex/masterFix "A...
# 21               not sure how that didn't come up already
# 22      Merge pull request #31 from xoddark/Werror_con...
# 23      Remove unnecessary finite variance restriction...
# 24                                 Fix SLLN abbreviation.
# 25                         Convert port number to integer
# 26                        Build w/ tentative CSV2 support
# 27      Merge pull request #32 from xoddark/Werror_par...
# 28      Add parentesis aroud '&' to avoid script warni...
# 29             Demote invalid equivalence to implication.
# ...                                                   ...
# 601047             audit: check new and old style patches
# 601048  macvim: Fix compilation on Mac OS X 10.9On Mav...
# 601049  Fix install_name_tool path for keg_only formul...
# 601050           boost: add option to build debug variant
# 601051                        Upgrade pgrouting to v2.0.0
# 601052  Handle invalid names in download strategiesWhe...
# 601053  Merge branch 'master' of https://github.com/mx...
# 601054  Merge branch 'master' of https://github.com/mx...
# 601055  Merge branch 'master' of https://github.com/mx...
# 601056  Merge branch 'master' of https://github.com/mx...
# 601057  Merge branch 'master' of https://github.com/mx...
# 601058  Merge branch 'master' of https://github.com/mx...
# 601059  Merge branch 'master' of https://github.com/mx...
# 601060  Merge branch 'master' of https://github.com/mx...
# 601061  Merge branch 'master' of https://github.com/mx...
# 601062  Merge branch 'master' of https://github.com/mx...
# 601063  Merge branch 'master' of https://github.com/mx...
# 601064  Merge branch 'master' of https://github.com/mx...
# 601065  Merge branch 'master' of https://github.com/mx...
# 601066  Merge branch 'master' of https://github.com/mx...
# 601067  Merge branch 'master' of https://github.com/mx...
# 601068                   graphicsmagick: Fix some options
# 601069    graphicsmagick: Fix the svg-related option code
# 601070                                    gstreamer 1.2.0
# 601071                             gst-plugins-base 1.2.0
# 601072                             gst-plugins-good 1.2.0
# 601073                              gst-plugins-bad 1.2.0
# 601074                              update version of ack
# 601075  geoserver 2.4.0http://blog.geoserver.org/2013/...
# 601076  geoserver 2.4.0http://blog.geoserver.org/2013/...
#
#               labels_predicted
# 0            __label__features
# 1          __label__corrective
# 2       __label__nonfunctional
# 3          __label__perfective
# 4            __label__features
# 5       __label__nonfunctional
# 6            __label__features
# 7          __label__perfective
# 8          __label__corrective
# 9       __label__nonfunctional
# 10            __label__unknown
# 11           __label__features
# 12         __label__perfective
# 13           __label__features
# 14         __label__corrective
# 15      __label__nonfunctional
# 16         __label__perfective
# 17           __label__features
# 18         __label__perfective
# 19         __label__corrective
# 20      __label__nonfunctional
# 21         __label__perfective
# 22      __label__nonfunctional
# 23         __label__perfective
# 24         __label__perfective
# 25           __label__features
# 26           __label__features
# 27      __label__nonfunctional
# 28         __label__perfective
# 29           __label__features
# ...                        ...
# 601047       __label__features
# 601048  __label__nonfunctional
# 601049     __label__corrective
# 601050       __label__features
# 601051     __label__perfective
# 601052     __label__corrective
# 601053       __label__features
# 601054     __label__corrective
# 601055       __label__features
# 601056       __label__features
# 601057       __label__features
# 601058     __label__perfective
# 601059     __label__corrective
# 601060     __label__corrective
# 601061       __label__features
# 601062     __label__corrective
# 601063  __label__nonfunctional
# 601064     __label__perfective
# 601065       __label__features
# 601066     __label__corrective
# 601067       __label__features
# 601068     __label__perfective
# 601069       __label__features
# 601070     __label__perfective
# 601071     __label__perfective
# 601072     __label__perfective
# 601073     __label__perfective
# 601074       __label__features
# 601075     __label__perfective
# 601076     __label__perfective
#
# [601077 rows x 2 columns]

# %% [markdown]
# ##### End!
